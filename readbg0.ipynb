# %% [markdown]
# <a href="https://colab.research.google.com/github/Potdooshami/SVO_gapmap/blob/main/readbg0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/drive')
fn = '/content/drive/MyDrive/svo/fromMatlab/svo.h5'  # Replace with your actual file path
fn = '/content/drive/MyDrive/svo/fromMatlab/bg.h5'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def loadh5(fn):
  with h5py.File(fn, 'r') as f:
    for key in f.keys():
        data = f[key][:]  # Load the dataset
        rank = data.ndim  # Get the rank
        transpose_order = tuple(range(rank - 1, -1, -1))  # Create transpose order
        globals()[key] = np.transpose(data, transpose_order)  # Transpose and assign
loadh5(fn)

# %%
with h5py.File(fn, 'r') as f:
    for key in f.keys():
        data = f[key][:]  # Load the dataset
        rank = data.ndim  # Get the rank
        transpose_order = tuple(range(rank - 1, -1, -1))  # Create transpose order
        globals()[key] = np.transpose(data, transpose_order)  # Transpose and assign

# %%
fig,axs = plt.subplots(1,5,figsize = (10, 2))
for ind,ax in enumerate(axs):
  ax.imshow(dt[:,:,ind])
